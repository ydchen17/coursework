# %%
library(meta)
library(openxlsx)

# %%
getSheetNames("Dataset_data_curated_final.xlsx")
# Out:
# [1] "caregiver_Burden"       "caregiver_MentalHealth" "caregiver_Behaviour"

# %%
caregiver_Burden <- mental_health <- read.xlsx("Dataset_data_curated_final.xlsx", "caregiver_Burden")
caregiver_MentalHealth <- read.xlsx("Dataset_data_curated_final.xlsx", "caregiver_MentalHealth")
caregiver_Behaviour <- read.xlsx("Dataset_data_curated_final.xlsx", "caregiver_Behaviour")

# %%
caregiver_Burden
# Out:
#    Study.Identifier      Year
# 1  Amit 2008             2008
# 2  Amit 2008             2008
# 3  Pahlavanzadeh 2010    2010
# 4  Pahlavanzadeh 2010    2010
# 5  Guerra 2011           2011
# 6  Guerra 2011           2011
# 7  Aboulafia-Brakha 2014 2014
# 8  Aboulafia-Brakha 2014 2014
# 9  Kamkhagi 2015         2015
# 10 Kamkhagi 2015         2015
# 11 Söylemez 2016         2016
# 12 Söylemez 2016         2016
# 13 Shata 2017            2017
# 14 Shata 2017            2017
# 15 Lök 2017              2017
# 16 Lök 2017              2017
# 17 Novelli 2018          2018
# 18 Novelli 2018          2018
# 19 Mercedeh 2014         2014
# 20 Mercedeh 2014         2014
# 21 Lin 2017              2017
# 22 Lin 2017              2017
# 23 Hinton 2020           2020
# 24 Hinton 2020           2020
# 25 Chen 2020             2020
# 26 Chen 2020             2020
# 27 Uyar 2019             2019
# 28 Uyar 2019             2019
# 29 Govindakumari 2020    2020
# 30 Govindakumari 2020    2020
# ...
